# %%
######## SMB ########

import pandas as pd
import matplotlib.pyplot as plt

fontsize=16
# Excel dosyasından verileri oku
excel_path = '/Users/nurullah/Desktop/galaxy_abudance/Uzak_Pc/08122023.xlsx'
data = pd.read_excel(excel_path, sheet_name='smb_bpt')

x_exp_HII = [-0.43, 1.27, 3]
y_exp_HII = [-0.56, 0.38, 1.76]

x2_exp_HII = [0.40, 0.70, 1.46]
y2_exp_HII = [0.22, 1.18, 2.00]

x_exp_SNR = [-0.43, 0.40, 0.40, 0.59, 0.00, -0.43]
y_exp_SNR = [-0.56, -0.10, 0.22, 0.82, 0.82, -0.56]

x_exp_PNe = [-0.13, 3]
y_exp_PNe = [-1.50, 0.09]

x2_exp_PNe = [-1.00, 3.00]
y2_exp_PNe = [-0.899, 2.245]

# Grafik çizimi
plt.figure(figsize=(8, 8))

# Her bir veri setini çizim
plt.plot(x_exp_HII, y_exp_HII, 'k--', label='H II')
plt.plot(x2_exp_HII, y2_exp_HII, 'k--')

plt.plot(x_exp_SNR, y_exp_SNR, 'b--', label='SNR')

plt.plot(x_exp_PNe, y_exp_PNe, 'r-', label='PNe')
plt.plot(x2_exp_PNe, y2_exp_PNe, 'r-')

# Excel verilerini küçük kırmızı nokta olarak ekle
plt.scatter(data['LOG(HS2)'], data['LOG(HN2)'], c='green', s=1, label='True PN')

# Eksen etiketleri ve başlık
plt.xlabel(('LOG(Hα/[S II])') , fontsize=13)
plt.ylabel(('LOG(Hα/[N II])'), fontsize=13)
#plt.title('SNR, HII ve PNe Bölgelerini Gösteren Çizgiler')
plt.text(0.85, -0.35, "PN", {"size": fontsize, "color": "Red"})
plt.text(-0.15, 0.25, "SNR", {"size": fontsize, "color": "Blue"})
plt.text(1.2, 1.3, "H II", {"size": fontsize, "color": "Black"})
# Legend ekleme
plt.legend()

# Grid eklemek istiyorsanız kullanabilirsiniz.
plt.grid(True)
#plt.savefig('/Users/nurullah/Desktop/galaxy_abudance/Uzak_Pc/deneme_SMB.png', bbox_inches='tight', dpi=300)
# Grafik gösterme
plt.show()

# Grafik dosyasını PNG olarak kaydetme

# %%
import pandas as pd
import matplotlib.pyplot as plt

fontsize = 16
# Excel dosyasından verileri oku
excel_path = '/Users/nurullah/Desktop/galaxy_abudance/Uzak_Pc/sigma_5/bilgiislem/deneme/Sigma_5_renkli.xlsx'
data = pd.read_excel(excel_path, sheet_name='smb_bpt')

# Renk haritası oluştur
color_map = {
    'Bulge': 'blue',
    'Thin Disc': 'red',
    'Thick Disk': 'green',
    'Halo': 'orange',
    'no distance': 'grey',
    'no data': 'black'
}

# Veri noktaları için renkleri belirle
colors = data['Gbileşen'].map(color_map)

# Ekspresyon verileri
x_exp_HII = [-0.43, 1.27, 3]
y_exp_HII = [-0.56, 0.38, 1.76]

x2_exp_HII = [0.40, 0.70, 1.46]
y2_exp_HII = [0.22, 1.18, 2.00]

x_exp_SNR = [-0.43, 0.40, 0.40, 0.59, 0.00, -0.43]
y_exp_SNR = [-0.56, -0.10, 0.22, 0.82, 0.82, -0.56]

x_exp_PNe = [-0.13, 3]
y_exp_PNe = [-1.50, 0.09]

x2_exp_PNe = [-1.00, 3.00]
y2_exp_PNe = [-0.899, 2.245]

# Grafik çizimi
plt.figure(figsize=(8, 8))

# Her bir veri setini çizim
plt.plot(x_exp_HII, y_exp_HII, 'k--', label='H II')
plt.plot(x2_exp_HII, y2_exp_HII, 'k--')

plt.plot(x_exp_SNR, y_exp_SNR, 'b--', label='SNR')

plt.plot(x_exp_PNe, y_exp_PNe, 'r-', label='PNe')
plt.plot(x2_exp_PNe, y2_exp_PNe, 'r-')

# Excel verilerini küçük kırmızı nokta olarak ekle
plt.scatter(data['LOG(HS2)'], data['LOG(HN2)'], c=colors, s=5, label='True PN')

# Eksen etiketleri ve başlık
plt.xlabel(('LOG(Hα/[S II])'), fontsize=13)
plt.ylabel(('LOG(Hα/[N II])'), fontsize=13)

# Bölge isimlerini ekle
plt.text(1.65, -0.35, "PN", {"size": fontsize, "color": "Red"})
plt.text(0.15, 0.25, "SNR", {"size": fontsize, "color": "Blue"})
plt.text(1.2, 1.3, "H II", {"size": fontsize, "color": "Black"})

# Legend ekleme
plt.legend()

# Grid eklemek istiyorsanız kullanabilirsiniz.
plt.grid(True)

# Grafik dosyasını PNG olarak kaydetme
#plt.savefig('/Users/nurullah/Desktop/galaxy_abudance/Uzak_Pc/sigma_5/bilgiislem/deneme/deneme_SMB.png', bbox_inches='tight', dpi=300)

# Grafik gösterme
plt.show()

# %%
######### BPT a #########

import pandas as pd
import matplotlib.pyplot as plt

fontsize=16
# Excel dosyasından verileri oku
excel_path = '/Users/nurullah/Desktop/galaxy_abudance/Uzak_Pc/08122023.xlsx'
data = pd.read_excel(excel_path, sheet_name='smb_bpt')

# Veriler
x_exp_SNR = [-0.50, -0.50, -0.10]
y_exp_SNR = [-1.50, 0.19, 2.00]
e_exp_PNe = [-2.50, 1.50]
y_exp_PNe = [1.30, 1.30]

# Grafik çizimi
plt.figure(figsize=(8, 8))

plt.plot(x_exp_SNR, y_exp_SNR, 'b--')
plt.plot(e_exp_PNe, y_exp_PNe, 'r-')
# Her bir veri setini çizim
#plt.plot(x_exp_HII, y_exp_HII, 'k--', label='H II')
#plt.plot(x_exp_SNR, y_exp_SNR, 'b--', label='SNR')
#plt.plot(x_exp_PNe, y_exp_PNe, 'r-', label='PNe')

# Excel verilerini küçük kırmızı nokta olarak ekle
plt.scatter(data['LOG(N2H)'], data['LOG(O3H2)'], c='green', s=1, label='True PN')

# Eksen etiketleri ve başlık
plt.xlabel(('LOG([S II])/Hα)'), fontsize=13)
plt.ylabel(('LOG([O III] 5007/Hβ)'), fontsize=13)
#plt.title('SNR, HII ve PNe Bölgelerini Gösteren Çizgiler')
plt.text(-0.8, 0.8, "PN", {"size": fontsize, "color": "Red"})
plt.text(0.2, 0.10, "SNR", {"size": fontsize, "color": "Blue"})
plt.text(-1.5, 0.3, "H II", {"size": fontsize, "color": "Black"})
# Legend ekleme
plt.legend()

# Grid eklemek istiyorsanız kullanabilirsiniz.
plt.grid(True)
#plt.savefig('/Users/nurullah/Desktop/galaxy_abudance/Uzak_Pc/deneme_BPTa.png', bbox_inches='tight', dpi=300)
# Grafik gösterme
plt.show()

# %%
######### BPT a #########   Sigma 5 

import pandas as pd
import matplotlib.pyplot as plt

fontsize=16
# Excel dosyasından verileri oku
excel_path = '/Users/nurullah/Desktop/galaxy_abudance/Uzak_Pc/sigma_5/bilgiislem/deneme/Sigma_5.xlsx'
data = pd.read_excel(excel_path, sheet_name='smb_bpt')

# Veriler
x_exp_SNR = [-0.50, -0.50, -0.10]
y_exp_SNR = [-1.50, 0.19, 2.00]
e_exp_PNe = [-2.50, 1.50]
y_exp_PNe = [1.30, 1.30]

# Grafik çizimi
plt.figure(figsize=(8, 8))

plt.plot(x_exp_SNR, y_exp_SNR, 'b--')
plt.plot(e_exp_PNe, y_exp_PNe, 'r-')
# Her bir veri setini çizim
#plt.plot(x_exp_HII, y_exp_HII, 'k--', label='H II')
#plt.plot(x_exp_SNR, y_exp_SNR, 'b--', label='SNR')
#plt.plot(x_exp_PNe, y_exp_PNe, 'r-', label='PNe')

# Excel verilerini küçük kırmızı nokta olarak ekle
plt.scatter(data['LOG(N2H)'], data['LOG(O3H2)'], c='green', s=1, label='True PN')

# Eksen etiketleri ve başlık
plt.xlabel(('LOG([S II])/Hα)'), fontsize=13)
plt.ylabel(('LOG([O III] 5007/Hβ)'), fontsize=13)
#plt.title('SNR, HII ve PNe Bölgelerini Gösteren Çizgiler')
plt.text(-0.8, 0.8, "PN", {"size": fontsize, "color": "Red"})
plt.text(0.2, 0.10, "SNR", {"size": fontsize, "color": "Blue"})
plt.text(-1.5, 0.3, "H II", {"size": fontsize, "color": "Black"})
# Legend ekleme
plt.legend()

# Grid eklemek istiyorsanız kullanabilirsiniz.
plt.grid(True)
#plt.savefig('/Users/nurullah/Desktop/galaxy_abudance/Uzak_Pc/sigma_5/bilgiislem/deneme/deneme_BPTa.png', bbox_inches='tight', dpi=300)
# Grafik gösterme
plt.show()

# %%
######### BPT b #########

from scipy.interpolate import interp1d
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
fontsize=16
# Excel dosyasından verileri oku
excel_path = '/Users/nurullah/Desktop/galaxy_abudance/Uzak_Pc/08122023.xlsx'
data = pd.read_excel(excel_path, sheet_name='smb_bpt')

# Veriler
x_exp_HII = [-0.40, -3]
y_exp_HII = [0.30, 0.99]

x_exp_SNR = [-0.40, -0.40, 0.09]
y_exp_SNR = [-1.49, 0.30, 1.99]

x_exp_PNe = [-4, -0.41, -0.16, -0.00, -0.00]
y_exp_PNe = [1.30, 1.30, 1.15, 0.90, 0.00]

# Grafik çizimi
plt.figure(figsize=(8, 8))

# Her bir veri setini çizim
plt.plot(x_exp_HII, y_exp_HII, 'k--', label='H II')
plt.plot(x_exp_SNR, y_exp_SNR, 'b--', label='SNR')
plt.plot(x_exp_PNe, y_exp_PNe, 'r-', label='PNe')

# Excel verilerini küçük kırmızı nokta olarak ekle
plt.scatter(data['LOG(S2H)'], data['LOG(O3H2)'], c='green', s=1, label='True PN')

# Eksen etiketleri ve başlık
plt.xlabel('LOG([S II]/Hα)', fontsize=13)
plt.ylabel('LOG([O III] 5007/Hβ)', fontsize=13)
#plt.title('SNR, HII ve PNe Bölgelerini Gösteren Çizgiler')
plt.text(-0.8, 0.8, "PN", {"size": fontsize, "color": "Red"})
plt.text(0.2, 0.10, "SNR", {"size": fontsize, "color": "Blue"})
plt.text(-1.5, 0.3, "H II", {"size": fontsize, "color": "Black"})
# Legend ekleme
plt.legend()

# Grid eklemek istiyorsanız kullanabilirsiniz.
plt.grid(True)
#plt.savefig('/Users/nurullah/Desktop/galaxy_abudance/Uzak_Pc/deneme_BPTb.png', bbox_inches='tight', dpi=300)
# Grafik gösterme
plt.show()

# %%
from scipy.interpolate import interp1d
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

fontsize = 16
# Excel dosyasından verileri oku
excel_path = '/Users/nurullah/Desktop/galaxy_abudance/Uzak_Pc/sigma_5/bilgiislem/deneme/Sigma_5_renkli.xlsx'
data = pd.read_excel(excel_path, sheet_name='smb_bpt')

# Veriler
x_exp_HII = [-0.40, -3]
y_exp_HII = [0.30, 0.99]

x_exp_SNR = [-0.40, -0.40, 0.09]
y_exp_SNR = [-1.49, 0.30, 1.99]

x_exp_PNe = [-4, -0.41, -0.16, -0.00, -0.00]
y_exp_PNe = [1.30, 1.30, 1.15, 0.90, 0.00]

# Renk haritası oluştur
color_map = {
    'Bulge': 'blue',
    'Thin Disc': 'red',
    'Thick Disk': 'green',
    'Halo': 'orange',
    'no distance': 'grey',
    'no data': 'black'
}

# Veri noktaları için renkleri belirle
colors = data['Gbileşen'].map(color_map)

# Grafik çizimi
plt.figure(figsize=(8, 8))

# Her bir veri setini çizim
plt.plot(x_exp_HII, y_exp_HII, 'k--', label='H II')
plt.plot(x_exp_SNR, y_exp_SNR, 'b--', label='SNR')
plt.plot(x_exp_PNe, y_exp_PNe, 'r-', label='PNe')

# Excel verilerini küçük nokta olarak ekle
plt.scatter(data['LOG(S2H)'], data['LOG(O3H2)'], c=colors, s=10, label='True PN')

# Eksen etiketleri ve başlık
plt.xlabel('LOG([S II]/Hα)', fontsize=13)
plt.ylabel('LOG([O III] 5007/Hβ)', fontsize=13)

# Bölge isimlerini ekle
plt.text(-0.8, 0.8, "PN", {"size": fontsize, "color": "Red"})
plt.text(0.2, 0.10, "SNR", {"size": fontsize, "color": "Blue"})
plt.text(-1.5, 0.3, "H II", {"size": fontsize, "color": "Black"})

# Legend ekleme
plt.legend()

# Grid eklemek istiyorsanız kullanabilirsiniz.
plt.grid(True)

# Grafik dosyasını PNG olarak kaydetme
#plt.savefig('/Users/nurullah/Desktop/galaxy_abudance/Uzak_Pc/sigma_5/bilgiislem/deneme/deneme_BPTb.png', bbox_inches='tight', dpi=300)

# Grafik gösterme
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.interpolate import interp1d
from adjustText import adjust_text
import matplotlib.patches as mpatches

fig = plt.figure(figsize=(16,9))
#fig.set_size_inches(13, 9)
ax = fig.add_subplot(1,1,1)
plt.xlim(-3.0,1.0)
plt.ylim(-1.5,2.0)
 
#data = pd.read_excel('/Users/utkantemiz/Desktop/TUBITAK1001/Paper_1/diagnostic_diagrams_paper_1.xlsx')
excel_path = pd.read_excel('/Users/nurullah/Desktop/galaxy_abudance/Uzak_Pc/sigma_5/bilgiislem/deneme/Sigma_5.xlsx')
data = pd.read_excel(excel_path, sheet_name='Sayfa4')

x = data['LOG(S2H)']
y = data['LOG(O3H2)']
 
x_data = np.linspace(-3,0.1,100)
y_data = (0.72 / (x_data - 0.32)) + 1.30
 
y_f = interp1d(x_data, y_data, 'cubic')
yf = y_f(x_data)
plt.plot(x_data,yf, 'k--')
 
data1 = pd.read_excel('/Users/nurullah/python_kodlar/BPT_b_HII_regions.xlsx')
 
x1 = data1['LOG1']
y1 = data1['LOG2']
 
plt.scatter(x1, y1, c='black', marker='s', alpha=0.5)
 
data2 = pd.read_csv('/Users/nurullah/python_kodlar/BPT_b_SNR.csv', sep='\t')
 
x2 = data2['LOG1']
y2 = data2['LOG2']
 
plt.scatter(x2, y2, c='blue', marker='v', alpha=0.5)
 
x_exp_HII = [-0.40, -3]
y_exp_HII = [0.30, 0.99]
x_exp_SNR = [-0.40, -0.40, 0.09]
y_exp_SNR = [-1.49, 0.30, 1.99]
x_exp_PNe = [-3, -0.41, -0.16, -0.00, -0.00]
y_exp_PNe = [1.30, 1.30, 1.15, 0.90, 0.00]
 
plt.plot(x_exp_HII, y_exp_HII, 'k--')
plt.plot(x_exp_SNR, y_exp_SNR, 'b--')
plt.plot(x_exp_PNe, y_exp_PNe, 'r-')
 
 
# Create a dictionary to store legend labels and markers
legend_labels = {}
Ticket2 = data['Ticket2']
annotations1 = []
for i, txt in enumerate(n1):
    if not pd.isna(Ticket2[i]) and str(Ticket2[i]) != 'nan':  # Exclude 'nan' label
        marker = legend_labels.get(Ticket2[i])  # Get the marker from the dictionary if it exists
        if Ticket2[i] == 'Likely PN':
            marker = 's'
        else:
            marker = 's'
        legend_labels[Ticket2[i]] = marker  # Add the marker to the dictionary
        annotations1.append(plt.text(x[i], y[i], txt, fontsize=fontsize))
        plt.scatter(x[i], y[i], c='red', marker=marker, s=100, alpha=1)
 
adjust_text(annotations1, expand_points=(1.3, 1.3))
 
# Create legend handles and labels based on the dictionary
legend_handles = [plt.Line2D([], [], marker=marker, color='red', linestyle='None', markersize=8)
                  for marker in legend_labels.values()]
legend_labels = list(legend_labels.keys())
 
# Display the legend
plt.legend(legend_handles, legend_labels, fontsize=fontsize)
 
 
 
ax.xaxis.set_tick_params(labelsize='x-large')
ax.yaxis.set_tick_params(labelsize='x-large')
 
plt.text(0.8, -1.4,"(b)", {"size":fontsize,"color":"Black"})
plt.text(-1.25,1.00,"PN", {"size":fontsize,"color":"Red"})
plt.text(0.15, 0, "SNR",{"size":fontsize,"color":"Blue"})
plt.text(-1.5, -0.5, "H II",{"size":fontsize,"color":"Black"})
#plt.legend(fontsize=fontsize)
plt.xlabel('LOG([S II]/Hα)', fontsize=fontsize)
plt.ylabel('LOG([O III] 5007/Hβ)', fontsize=fontsize)
#plt.title('BPT Tanısal Grafiği')
#plt.title('BPT Diagnostic Plot')
#plt.savefig('/Users/utkantemiz/Desktop/TUBITAK1001/Paper_1/figures/BPT_b_paper_1_final_3.png', bbox_inches='tight', dpi=100)
#plt.savefig('/Users/nurullah/Desktop/galaxy_abudance/Uzak_Pc/sigma_5/bilgiislem/deneme/B.png', bbox_inches='tight', dpi=100)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.interpolate import interp1d
from adjustText import adjust_text

# Font size definition
fontsize = 12  # or any other size

fig = plt.figure(figsize=(16,9))
#fig.set_size_inches(13, 9)
ax = fig.add_subplot(1,1,1)
plt.xlim(-3.0,1.0)
plt.ylim(-1.5,2.0)

# Load the Excel file correctly
data = pd.read_excel('/Users/nurullah/Desktop/galaxy_abudance/Uzak_Pc/sigma_5/bilgiislem/deneme/Sigma_5.xlsx', sheet_name='smb_bpt')

# Check and clean NaN and infinite values
data = data.replace([np.inf, -np.inf], np.nan).dropna(subset=['LOG(S2H)', 'LOG(O3H2)'])

x = data['LOG(S2H)']
y = data['LOG(O3H2)']

x_data = np.linspace(-3, 0.1, 100)
y_data = (0.72 / (x_data - 0.32)) + 1.30

y_f = interp1d(x_data, y_data, 'cubic')
yf = y_f(x_data)

# Plot the curve
plt.plot(x_data, yf, 'k--')
plt.scatter(x, y, color='red', s=10)  # Add scatter plot to visualize points

# Load additional data
data1 = pd.read_excel('/Users/nurullah/python_kodlar/BPT_b_HII_regions.xlsx')

# Check and clean NaN and infinite values
data1 = data1.replace([np.inf, -np.inf], np.nan).dropna(subset=['LOG1', 'LOG2'])

x1 = data1['LOG1']
y1 = data1['LOG2']

plt.scatter(x1, y1, c='black', marker='s', alpha=0.5, s=1)

data2 = pd.read_csv('/Users/nurullah/python_kodlar/BPT_b_SNR.csv', sep='\t')

# Check and clean NaN and infinite values
data2 = data2.replace([np.inf, -np.inf], np.nan).dropna(subset=['LOG1', 'LOG2'])

x2 = data2['LOG1']
y2 = data2['LOG2']

plt.scatter(x2, y2, c='blue', marker='v', alpha=0.5, s=1)

x_exp_HII = [-0.40, -3]
y_exp_HII = [0.30, 0.99]
x_exp_SNR = [-0.40, -0.40, 0.09]
y_exp_SNR = [-1.49, 0.30, 1.99]
x_exp_PNe = [-3, -0.41, -0.16, -0.00, -0.00]
y_exp_PNe = [1.30, 1.30, 1.15, 0.90, 0.00]

plt.plot(x_exp_HII, y_exp_HII, 'k--')
plt.plot(x_exp_SNR, y_exp_SNR, 'b--')
plt.plot(x_exp_PNe, y_exp_PNe, 'r-')

# Ensure n1 variable is defined
n1 = data['Ticket2']  # or an appropriate column

# Filter data for "True PN" entries
true_pn_indices = data[data['Ticket2'] == 'True PN'].index
annotations1 = []

for i in true_pn_indices:
    if np.isfinite(x.iloc[i]) and np.isfinite(y.iloc[i]):  # Only work with valid values
        plt.scatter(x.iloc[i], y.iloc[i], c='red', marker='s', s=1, alpha=1)

# Adjust text for a single "True PN" label
if len(true_pn_indices) > 0:
    first_index = true_pn_indices[0]
    annotations1.append(plt.text(x.iloc[first_index], y.iloc[first_index], 'True PN', fontsize=fontsize))
    adjust_text(annotations1, expand_points=(1.3, 1.3))

ax.xaxis.set_tick_params(labelsize='x-large')
ax.yaxis.set_tick_params(labelsize='x-large')

plt.text(0.8, -1.4, "(b)", {"size": fontsize, "color": "Black"})
plt.text(-1.25, 1.00, "PN", {"size": fontsize, "color": "Red"})
plt.text(0.15, 0, "SNR", {"size": fontsize, "color": "Blue"})
plt.text(-1.5, -0.5, "H II", {"size": fontsize, "color": "Black"})

plt.xlabel('LOG([S II]/Hα)', fontsize=fontsize)
plt.ylabel('LOG([O III] 5007/Hβ)', fontsize=fontsize)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 75
#      72 annotations1 = []
#      74 for i in true_pn_indices:
# ---> 75     if np.isfinite(x.iloc[i]) and np.isfinite(y.iloc[i]):  # Only work with valid values
#      76         plt.scatter(x.iloc[i], y.iloc[i], c='red', marker='s', s=1, alpha=1)
#      78 # Adjust text for a single "True PN" label
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1714, in _iLocIndexer._getitem_axis(self, key, axis)
#    1711     raise TypeError("Cannot index by location index with a non-integer key")
#    1713 # validate the location
# -> 1714 self._validate_integer(key, axis)
#    1716 return self.obj._ixs(key, axis=axis)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1647, in _iLocIndexer._validate_integer(self, key, axis)
#    1645 len_axis = len(self.obj._get_axis(axis))
#    1646 if key >= len_axis or key < -len_axis:
# -> 1647     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds
