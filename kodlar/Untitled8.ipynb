# %%
###################################################################################
######################################### BPT a ###################################
###################################################################################
 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.interpolate import interp1d
from adjustText import adjust_text
import matplotlib.patches as mpatches
 
fontsize = 16
fig = plt.figure(figsize=(16, 9))
ax = fig.add_subplot(1, 1, 1)
plt.xlim(-2.5, 1.5)
plt.ylim(-2.0, 2.0)
 
#data = pd.read_excel('/Users/utkantemiz/Desktop/TUBITAK1001/Paper_1/diagnostic_diagrams_paper_1.xlsx')
excel_path = '/Users/nurullah/Desktop/RTT150/3_cü_rapor.xlsx'
data = pd.read_excel(excel_path, sheet_name='smb_bpt')
 
x = data['LOG(N2H)']
y = data['LOG(O3H2)']
n1 = data['Ticket']
 
x_data = np.linspace(-2.5, 0.3, 1000)
y_data = (0.61 / (x_data - 0.47)) + 1
 
y_f = interp1d(x_data, y_data, 'cubic')
yf = y_f(x_data)
plt.plot(x_data, yf, 'k--')
 
data1 = pd.read_csv('/Users/nurullah/python_kodlar/BPT_a_HII_region.csv', sep='\t')
 
x1 = data1['LOG1']
y1 = data1['LOG2']
 
plt.scatter(x1, y1, c='black', marker='s', alpha=0.35)
 
data3 = pd.read_csv('/Users/nurullah/python_kodlar/BPT_a_SNR.csv', sep='\t')
 
x3 = data3['LOG1']
y3 = data3['LOG2']
 
plt.scatter(x3, y3, c='blue', marker='v', alpha=0.5)
 
x_exp_SNR = [-0.50, -0.50, -0.10]
y_exp_SNR = [-2.0, 0.19, 2.00]
e_exp_PNe = [-2.50, 1.50]
y_exp_PNe = [1.30, 1.30]
 
plt.plot(x_exp_SNR, y_exp_SNR, 'b--')
plt.plot(e_exp_PNe, y_exp_PNe, 'r-')
 
 
# Create a dictionary to store legend labels and markers
legend_labels = {}
Ticket2 = data['Ticket2']
annotations1 = []
for i, txt in enumerate(n1):
    if not pd.isna(Ticket2[i]) and str(Ticket2[i]) != 'nan':  # Exclude 'nan' label
        marker = legend_labels.get(Ticket2[i])  # Get the marker from the dictionary if it exists
        if Ticket2[i] == 'Likely PN':
            marker = 's'
        else:
            marker = 's'
        legend_labels[Ticket2[i]] = marker  # Add the marker to the dictionary
        annotations1.append(plt.text(x[i], y[i], txt, fontsize=fontsize))
        plt.scatter(x[i], y[i], c='red', marker=marker, s=100, alpha=1)
 
adjust_text(annotations1, expand_points=(1.3, 1.3))
 
# Create legend handles and labels based on the dictionary
legend_handles = [plt.Line2D([], [], marker=marker, color='red', linestyle='None', markersize=8)
                  for marker in legend_labels.values()]
legend_labels = list(legend_labels.keys())
 
# Display the legend
plt.legend(legend_handles, legend_labels, fontsize=fontsize)
 
 
ax.xaxis.set_tick_params(labelsize='x-large')
ax.yaxis.set_tick_params(labelsize='x-large')
 
plt.text(1.3, -1.9, "(a)", {"size": fontsize, "color": "Black"})
plt.text(-0.8, 0.8, "PN", {"size": fontsize, "color": "Red"})
plt.text(0.25, 0, "SNR", {"size": fontsize, "color": "Blue"})
plt.text(-1.5, -0.25, "H II", {"size": fontsize, "color": "Black"})
 
plt.xlabel('LOG([N II] 6584/Hα)', fontsize=fontsize)
plt.ylabel('LOG([O III] 5007/Hβ)', fontsize=fontsize)
#plt.savefig('/Users/utkantemiz/Desktop/TUBITAK1001/Paper_1/figures/BPT_a_paper_1_final_3.png', bbox_inches='tight', dpi=100)
plt.savefig('/Users/nurullah/Desktop/RTT150/3cürapor_BPT_a.png', bbox_inches='tight', dpi=100)
plt.show()
 
###################################################################################
######################################### BPT b ###################################
###################################################################################
 
fig = plt.figure(figsize=(16,9))
#fig.set_size_inches(13, 9)
ax = fig.add_subplot(1,1,1)
plt.xlim(-3.0,1.0)
plt.ylim(-2.0,2.0)
 
#data = pd.read_excel('/Users/utkantemiz/Desktop/TUBITAK1001/Paper_1/diagnostic_diagrams_paper_1.xlsx')
excel_path = '/Users/nurullah/Desktop/RTT150/3_cü_rapor.xlsx'
data = pd.read_excel(excel_path, sheet_name='smb_bpt')
 
x = data['LOG(S2H)']
y = data['LOG(O3H2)']
 
x_data = np.linspace(-3,0.1,100)
y_data = (0.72 / (x_data - 0.32)) + 1.30
 
y_f = interp1d(x_data, y_data, 'cubic')
yf = y_f(x_data)
plt.plot(x_data,yf, 'k--')
 
data1 = pd.read_excel('/Users/nurullah/python_kodlar/BPT_b_HII_regions.xlsx')
 
x1 = data1['LOG1']
y1 = data1['LOG2']
 
plt.scatter(x1, y1, c='black', marker='s', alpha=0.5)
 
data2 = pd.read_csv('/Users/nurullah/python_kodlar/BPT_b_SNR.csv', sep='\t')
 
x2 = data2['LOG1']
y2 = data2['LOG2']
 
plt.scatter(x2, y2, c='blue', marker='v', alpha=0.5)
 
x_exp_HII = [-0.40, -3]
y_exp_HII = [0.30, 0.99]
x_exp_SNR = [-0.40, -0.40, 0.09]
y_exp_SNR = [-2.0, 0.30, 1.99]
x_exp_PNe = [-3, -0.41, -0.16, -0.00, -0.00]
y_exp_PNe = [1.30, 1.30, 1.15, 0.90, 0.00]
 
plt.plot(x_exp_HII, y_exp_HII, 'k--')
plt.plot(x_exp_SNR, y_exp_SNR, 'b--')
plt.plot(x_exp_PNe, y_exp_PNe, 'r-')
 
 
# Create a dictionary to store legend labels and markers
legend_labels = {}
Ticket2 = data['Ticket2']
annotations1 = []
for i, txt in enumerate(n1):
    if not pd.isna(Ticket2[i]) and str(Ticket2[i]) != 'nan':  # Exclude 'nan' label
        marker = legend_labels.get(Ticket2[i])  # Get the marker from the dictionary if it exists
        if Ticket2[i] == 'Likely PN':
            marker = 's'
        else:
            marker = 's'
        legend_labels[Ticket2[i]] = marker  # Add the marker to the dictionary
        annotations1.append(plt.text(x[i], y[i], txt, fontsize=fontsize))
        plt.scatter(x[i], y[i], c='red', marker=marker, s=100, alpha=1)
 
adjust_text(annotations1, expand_points=(1.3, 1.3))
 
# Create legend handles and labels based on the dictionary
legend_handles = [plt.Line2D([], [], marker=marker, color='red', linestyle='None', markersize=8)
                  for marker in legend_labels.values()]
legend_labels = list(legend_labels.keys())
 
# Display the legend
plt.legend(legend_handles, legend_labels, fontsize=fontsize)
 
 
 
ax.xaxis.set_tick_params(labelsize='x-large')
ax.yaxis.set_tick_params(labelsize='x-large')
 
plt.text(0.8, -1.9,"(b)", {"size":fontsize,"color":"Black"})
plt.text(-0.5,0.7,"PN", {"size":fontsize,"color":"Red"})
plt.text(0.15, 0, "SNR",{"size":fontsize,"color":"Blue"})
plt.text(-1.5, -0.5, "H II",{"size":fontsize,"color":"Black"})
#plt.legend(fontsize=fontsize)
plt.xlabel('LOG([S II]/Hα)', fontsize=fontsize)
plt.ylabel('LOG([O III] 5007/Hβ)', fontsize=fontsize)
#plt.title('BPT Tanısal Grafiği')
#plt.title('BPT Diagnostic Plot')
#plt.savefig('/Users/utkantemiz/Desktop/TUBITAK1001/Paper_1/figures/BPT_b_paper_1_final_3.png', bbox_inches='tight', dpi=100)
plt.savefig('/Users/nurullah/Desktop/RTT150/3cürapor_BPT_b.png', bbox_inches='tight', dpi=100)
plt.show()
 
###################################################################################
########################################### SMB ###################################
###################################################################################
 
fontsize = 16
fig = plt.figure(figsize=(16, 9))
ax = fig.add_subplot(1, 1, 1)
plt.xlim(-1.0, 3.0)
plt.ylim(-1.5, 2.0)
 
#data = pd.read_excel('/Users/utkantemiz/Desktop/TUBITAK1001/Paper_1/diagnostic_diagrams_paper_1.xlsx')
excel_path = '/Users/nurullah/Desktop/RTT150/3_cü_rapor.xlsx'
data = pd.read_excel(excel_path, sheet_name='smb_bpt')
 
x = data['LOG(HS2)']
y = data['LOG(HN2)']
n1 = data['Ticket']
 
data1 = pd.read_excel('/Users/nurullah/python_kodlar/SMB_SNR_HII.xlsx')
 
x1 = data1['LOG(Hα/[S II])']
y1 = data1['LOG(Hα/[N II])']
 
plt.scatter(x1, y1, c='blue', marker='v', alpha=0.5)
 
data4 = pd.read_excel('/Users/nurullah/python_kodlar/SMB_SNR_HII.xlsx')
 
x4 = data4['Log1']
y4 = data4['Log2']
 
plt.scatter(x4, y4, c='black', marker='s', alpha=0.5)
 
x_exp_HII = [-0.43, 1.27, 3]
y_exp_HII = [-0.56, 0.38, 1.76]
x2_exp_HII = [0.40, 0.70, 1.46]
y2_exp_HII = [0.22, 1.18, 2.00]
x_exp_SNR = [-0.43, 0.40, 0.40, 0.59, 0.00, -0.43]
y_exp_SNR = [-0.56, -0.10, 0.22, 0.82, 0.82, -0.56]
x_exp_PNe = [-0.13, 3]
y_exp_PNe = [-1.50, 0.09]
x2_exp_PNe = [-1.00, 3.00]
y2_exp_PNe = [-0.899, 2.245]
 
plt.plot(x_exp_HII, y_exp_HII, 'k--')
plt.plot(x2_exp_HII, y2_exp_HII, 'k--')
plt.plot(x_exp_SNR, y_exp_SNR, 'b--')
plt.plot(x_exp_PNe, y_exp_PNe, 'r-')
plt.plot(x2_exp_PNe, y2_exp_PNe, 'r-')
 
 
# Create a dictionary to store legend labels and markers
legend_labels = {}
Ticket2 = data['Ticket2']
annotations1 = []
for i, txt in enumerate(n1):
    if not pd.isna(Ticket2[i]) and str(Ticket2[i]) != 'nan':  # Exclude 'nan' label
        marker = legend_labels.get(Ticket2[i])  # Get the marker from the dictionary if it exists
        if Ticket2[i] == 'Likely PN':
            marker = 's'
        else:
            marker = 's'
        legend_labels[Ticket2[i]] = marker  # Add the marker to the dictionary
        annotations1.append(plt.text(x[i], y[i], txt, fontsize=fontsize))
        if n1[i] == '044.6+00.4':
            plt.scatter(x[i], y[i], c='lightcoral', marker=marker, s=100, alpha=0.5)  # Change color to a more faded red
        else:
            plt.scatter(x[i], y[i], c='red', marker=marker, s=100, alpha=1)
 
adjust_text(annotations1, expand_points=(1.3, 1.3))
 
# Create legend handles and labels based on the dictionary
legend_handles = [plt.Line2D([], [], marker=marker, color='red', linestyle='None', markersize=8)
                  for marker in legend_labels.values()]
legend_labels = list(legend_labels.keys())
 
# Display the legend
plt.legend(legend_handles, legend_labels, fontsize=fontsize)
 
ax.xaxis.set_tick_params(labelsize='x-large')
ax.yaxis.set_tick_params(labelsize='x-large')
 
plt.text(0.85, -0.35, "PN", {"size": fontsize, "color": "Red"})
plt.text(-0.15, -0.25, "SNR", {"size": fontsize, "color": "Blue"})
plt.text(0.5, 1.3, "H II", {"size": fontsize, "color": "Black"})
 
plt.xlabel('LOG(Hα/[SII])', fontsize=fontsize)
plt.ylabel('LOG(Hα/[NII])', fontsize=fontsize)
 
#plt.savefig('/Users/utkantemiz/Desktop/TUBITAK1001/Paper_1/figures/SMB_paper_1_final_3.png', bbox_inches='tight', dpi=100)
plt.savefig('/Users/nurullah/Desktop/RTT150/3cürapor_SMB.png', bbox_inches='tight', dpi=100)
plt.show()
