# %%
import matplotlib.pyplot as plt

# Data
sources = [
    "019.8+05.6", "021.3+02.2", "034.5-11.7", "048.5+04.2",
    "050.4-01.6", "080.2+03.8", "095.2+25.4", "135.9+55.9",
    "153.7-01.4", "183.0+00.0", "202.9+07.4", "216.9-05.2"
]

elements = ["He/H", "N/H", "O/H", "Ne/H", "Ar/H", "S/H"]

# Abundance ratios
data = [
    [-0.8, -5.2, -3.8, -4.6, -5.6, -6.6],
    [-1.2, -4.9, -3.4, -999, -5.8, -6.4],
    [-2.3, -4.6, -4.2, -999, -999, -999],
    [-1.0, -6.7, -3.8, -4.5, -5.6, -999],
    [-1.0, -5.3, -3.5, -999, -6.8, -7.0],
    [-999, -999, -3.5, -999, -4.5, -999],
    [-0.9, -4.2, -3.8, -3.9, -6.1, -5.4],
    [-1.2, -999, -999, -999, -999, -999],
    [-1.0, -4.3, -3.5, -999, -5.9, -5.8],
    [-1.2, -6.6, -3.4, -4.2, -6.3, -999],
    [-1.2, -999, -3.9, -999, -999, -999],
    [-1.0, -999, -4.1, -4.7, -6.2, -999]
]

# Model Abundance ratios
data1 = [
    [-1.5, -3.9, -3.2, -4.4, -4.3, -6.5],
    [-1.3, -4.8, -3.6, -999, -5.8, -5.6],
    [-2.4, -4.4, -3.9, -999, -999, -999],
    [-0.5, -4.3, -3.6, -4.9, -6.0, -999],
    [-1.3, -4.9, -3.5, -999, -6.8, -6.0],
    [-999, -999, -3.4, -999, -4.5, -999],
    [-999, -4.6, -3.6, -3.4, -999, -4.7],
    [-1.0, -999, -999, -999, -999, -999],
    [-0.9, -4.2, -3.6, -999, -6.0, -5.2],
    [-2.0, -6.6, -3.3, -4.4, -6.4, -999],
    [-0.3, -999, -3.8, -999, -999, -999],
    [-0.6, -999, -3.6, -5.0, -6.2, -999],
]


fig, axs = plt.subplots(6, 1, figsize=(15, 20))
                       

#####################     He     #####################

# Extract N/H and O/H data with an offset of 12
He_H = [row[0] for row in data]  # N/H is at index 1
He_H1 = [row1[0] for row1 in data1]  # O/H is at index 2

# Plotting
axs[0].scatter(sources,He_H, color='blue',s=100,marker='s')
axs[0].scatter(sources,He_H1, color='red',s=100,marker='o')
axs[0].tick_params(axis='y', labelsize=13)
axs[0].set_xticklabels([])
axs[0].set_ylabel('Log(He/H)', fontsize=13)
axs[0].set_ylim(-2,0)

#####################     N     #####################

# Extract N/H and O/H data with an offset of 12
N_H = [row[1] for row in data]  # N/H is at index 1
N_H1 = [row1[1] for row1 in data1]  # O/H is at index 2

# Plotting
axs[1].scatter(sources,N_H, color='blue',s=100,marker='s')
axs[1].scatter(sources,N_H1, color='red',s=100,marker='o')
axs[1].tick_params(axis='y', labelsize=13)
axs[1].set_xticklabels([])
axs[1].set_ylabel('Log(N/H)', fontsize=13)
axs[1].set_ylim(-7,-3)

#####################     O     #####################

# Extract N/H and O/H data with an offset of 12
O_H = [row[2] for row in data]  # N/H is at index 1
O_H1 = [row1[2] for row1 in data1]  # O/H is at index 2

# Plotting
axs[2].scatter(sources,O_H, color='blue',s=100,marker='s')
axs[2].scatter(sources,O_H1, color='red',s=100,marker='o')
axs[2].tick_params(axis='y', labelsize=13)
axs[2].set_xticklabels([])
axs[2].set_ylabel('Log(O/H)', fontsize=13)
axs[2].set_ylim(-5,-3)

#####################     Ne     #####################

# Extract N/H and O/H data with an offset of 12
Ne_H = [row[3] for row in data]  # N/H is at index 1
Ne_H1 = [row1[3] for row1 in data1]  # O/H is at index 2

# Plotting
axs[3].scatter(sources,Ne_H, color='blue',s=100,marker='s')
axs[3].scatter(sources,Ne_H1, color='red',s=100,marker='o')
axs[3].tick_params(axis='y', labelsize=13)
axs[3].set_xticklabels([])
axs[3].set_ylabel('Log(Ne/H)', fontsize=13)
axs[3].set_ylim(-6,-3)

#####################     Ar     #####################

# Extract N/H and O/H data with an offset of 12
Ar_H = [row[4] for row in data]  # N/H is at index 1
Ar_H1 = [row1[4] for row1 in data1]  # O/H is at index 2

# Plotting
axs[4].scatter(sources,Ar_H, color='blue',s=100,marker='s')
axs[4].scatter(sources,Ar_H1, color='red',s=100,marker='o')
axs[4].tick_params(axis='y', labelsize=13)
axs[4].set_xticklabels([])
axs[4].set_ylabel('Log(Ar/H)', fontsize=13)
axs[4].set_ylim(-8,-4)

#####################     S     #####################

# Extract N/H and O/H data with an offset of 12
S_H = [row[5] for row in data]  # N/H is at index 1
S_H1 = [row1[5] for row1 in data1]  # O/H is at index 2

# Plotting
axs[5].scatter(sources,S_H, color='blue',s=100,marker='s', label="Data")
axs[5].scatter(sources,S_H1, color='red',s=100,marker='o', label="Model")
axs[5].tick_params(axis='y', labelsize=13)
axs[5].set_xlabel('PN G', fontsize=13)
axs[5].set_ylabel('Log(S/H)', fontsize=13)
axs[5].set_ylim(-8,-4)
axs[5].set_xticklabels(sources, fontsize=13)
axs[5].legend(loc = "lower right", fontsize=13,ncols=4)

plt.tight_layout(rect=[0, 0, 1, 0.99])
plt.savefig('/Users/nazimaksaker/Desktop/abun.pdf')   # save the figure to file
# Out:
# /var/folders/85/ht4dfkwj4k98y9czg2wl8xmm0000gn/T/ipykernel_81461/1723668932.py:131: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[5].set_xticklabels(sources, fontsize=13)
